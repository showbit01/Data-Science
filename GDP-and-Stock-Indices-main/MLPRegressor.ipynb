# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('/Users/shobhitsharma/Downloads/DataScience/Gdp-updated 2.csv')
df1
# Out:
#     Year  Agriculture, forestry & fishing  Mining & quarrying  Manufacturing  \
# 0   2011                           323222               64670         350857
# 1   2011                           270231               55463         329937
# 2   2011                           505545               65815         334727
# 3   2011                           402949               75087         394465
# 4   2012                           360094               75789         374606
# 5   2012                           302961               59899         395939
# 6   2012                           557597               70447         377768
# 7   2012                           454454               79707         424523
# 8   2013                           407713               70645         413131
# 9   2013                           350835               63145         424395
# 10  2013                           670113               74589         416194
# ...

# %%
df_2020=df1.iloc[36:,:]
df_new=df1.iloc[:-2,:]
df_new
# Out:
#     Year  Agriculture, forestry & fishing  Mining & quarrying  Manufacturing  \
# 0   2011                           323222               64670         350857
# 1   2011                           270231               55463         329937
# 2   2011                           505545               65815         334727
# 3   2011                           402949               75087         394465
# 4   2012                           360094               75789         374606
# 5   2012                           302961               59899         395939
# 6   2012                           557597               70447         377768
# 7   2012                           454454               79707         424523
# 8   2013                           407713               70645         413131
# 9   2013                           350835               63145         424395
# 10  2013                           670113               74589         416194
# ...

# %%
actual_gdp=df_2020.iloc[:, -1]
df_2020

ip=df_2020.iloc[:,0:-1]
ip=ip.iloc[:,1:]
#ip = scaler.fit_transform(ip)

# %%
actual_gdp
# Out:
# 36    3808193
# 37    4722068
# Name: GDP , dtype: int64

# %%
X = df_new.iloc[:, 0:-1]
Y = df_new.iloc[:, -1]
X=X.iloc[:,1:]
X
# Out:
#     Agriculture, forestry & fishing  Mining & quarrying  Manufacturing  \
# 0                            323222               64670         350857
# 1                            270231               55463         329937
# 2                            505545               65815         334727
# 3                            402949               75087         394465
# 4                            360094               75789         374606
# 5                            302961               59899         395939
# 6                            557597               70447         377768
# 7                            454454               79707         424523
# 8                            407713               70645         413131
# 9                            350835               63145         424395
# 10                           670113               74589         416194
# 11                           497711               87415         459732
# ...

# %%
#from sklearn import preprocessing
#Y = preprocessing.normalize([Y])
#x_array = np.array(df1['Total Gross Value Added at Basic Price'])
#Y=pd.DataFrame(Y.T)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split



model1 = MLPRegressor(hidden_layer_sizes=(8,8,8,8,8,8,8,8), max_iter=5000)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#     Agriculture, forestry & fishing  Mining & quarrying  Manufacturing  \
# 7                            454454               79707         424523
# 6                            557597               70447         377768
# 11                           497711               87415         459732
# 16                           499370               90269         530752
# 10                           670113               74589         416194
# 25                           544703               69310         633546
# 15                           539374               71822         495542
# 33                           608227               75826         687906
# 20                           573092               81934         575997
# 26                           903485               86182         620420
# 28                           655799               98202         664844
# 17                           424241               61138         534069
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)




model1.fit(X_train, Y_train)

model1
# Out:
# /Users/shobhitsharma/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=(8, 8, 8, 8, 8, 8, 8, 8), max_iter=5000)

# %%
from sklearn.metrics import mean_squared_error, r2_score
Ya = Y_test
Ya=Ya.to_numpy()
Yp = model1.predict(X_test)

mse = mean_squared_error(Ya, Yp)
R2 = r2_score(Ya, Yp)
'R2-Score : {}'.format(R2)
# Out:
# 'R2-Score : 0.9719720814568605'

# %%
ip = scaler.transform(ip)
ip

predicted_gdp=model1.predict(ip)

predicted_gdp
# Out:
# array([10805998.61907237, 10805967.28797651])

# %%
actual_gdp
# Out:
# 36    3808193
# 37    4722068
# Name: GDP , dtype: int64

# %%
#df1=pd.read_csv('/Users/shobhitsharma/Downloads/DataScience/gdp_data.csv')
#df2=pd.read_csv('/Users/shobhitsharma/Downloads/DataScience/nifty_data.csv')
#df3=pd.read_csv('/Users/shobhitsharma/Downloads/DataScience/sensex_data.csv')
#df2=df2.drop(['Adj Close'],axis=1)
#df3=df3.drop(['Adj Close'],axis=1)

# %%
#df2_new=df2.iloc[:,2:]
#df2_new=df2_new.rename({'Open': 'sensex_open', 'High': 'sensex_High','Low':'sensex_Low','Close': 'sensex_close', 'Volume': 'sensex_Volume'}, axis=1)

# %%
#df3_new=df3.iloc[:,2:]
#df3_new=df3_new.rename({'Open': 'nifty_open', 'High': 'nifty_High','Low':'nifty_Low','Close': 'nifty_close', 'Volume': 'nifty_Volume'}, axis=1)

# %%
#df3_new

# %%
#merge=pd.read_csv('/Users/shobhitsharma/Downloads/DataScience/file.csv')

#x=merge.iloc[:,2:]
#x=merge.iloc[:-2,:]

# %%
#merge
